# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
cities_data_df = pd.read_csv("cities.csv")
cities_data_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
# Create a scatter plot which compares latitude to temperature
cities_data_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8), color = "#7b8ab8",
              title="City Latitude vs Max Temperature")
plt.savefig("lat_temp.png")
plt.show()

# %%
# Create a scatter plot which compares latitude to humidity
cities_data_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8),
              title="City Latitude vs Humidity", color="#7b8ab8")
plt.savefig("lat_hum.png")
plt.show()

# %%
cities_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8),
              title="City Latitude vs Cloudiness", color="#7b8ab8")
plt.savefig("lat_cloud.png")
plt.show()

# %%
cities_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8),
              title="City Latitude vs Wind Speed", color="#7b8ab8")
plt.savefig("lat_speed.png")
plt.show()

# %%
city_social_df = pd.read_csv("uaScoresDataFrame.csv")
city_social_df.head(264)
# Out:
#       id      UA_Name             UA_Country   UA_Continent  Housing  \
# 0      0       Aarhus                Denmark         Europe   6.1315
# 1      1     Adelaide              Australia        Oceania   6.3095
# 2      2  Albuquerque             New Mexico  North America   7.2620
# 3      3       Almaty             Kazakhstan           Asia   9.2820
# 4      4    Amsterdam            Netherlands         Europe   3.0530
# ..   ...          ...                    ...            ...      ...
# 259  259   Washington   District of Columbia  North America   1.2105
# 260  260   Wellington            New Zealand        Oceania   5.1345
# 261  261     Winnipeg                 Canada  North America   7.5525
# 262  262      Wroclaw                 Poland         Europe   8.4520
# 263  263      Yerevan                Armenia           Asia   9.6945
#
#      Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# ...

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Cost of Living", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Cost of Living", color="#7b8ab8")
plt.savefig("lat_house.png")
plt.show()

# %%
city_social_df.dtypes
# Out:
# id                         int64
# UA_Name                   object
# UA_Country                object
# UA_Continent              object
# Housing                  float64
# Cost of Living           float64
# Startups                 float64
# Venture Capital          float64
# Travel Connectivity      float64
# Commute                  float64
# Business Freedom         float64
# Safety                   float64
# Healthcare               float64
# Education                float64
# Environmental Quality    float64
# Economy                  float64
# Taxation                 float64
# Internet Access          float64
# Leisure & Culture        float64
# Tolerance                float64
# Outdoors                  object
# Lat                      float64
# Lng                      float64
# dtype: object

# %%
# city_social_df = city_social_df.astype({"Lat": float})

# %%
city_social_df.dtypes
# Out:
# Unnamed: 0                 int64
# UA_Name                   object
# UA_Country                object
# UA_Continent              object
# Housing                  float64
# Cost of Living            object
# Startups                 float64
# Venture Capital          float64
# Travel Connectivity      float64
# Commute                  float64
# Business Freedom         float64
# Safety                   float64
# Healthcare               float64
# Education                float64
# Environmental Quality    float64
# Economy                  float64
# Taxation                 float64
# Internet Access          float64
# Leisure & Culture        float64
# Tolerance                float64
# Outdoors                  object
# Lat                       object
# Lng                      float64
# dtype: object

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Healthcare", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Access to Healthcare", color="#7b8ab8")
plt.savefig("lat_health.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Education", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Educational Prospects", color="#7b8ab8")
plt.savefig("lat_edu.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Environmental Quality", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Environmental Quality", color="#7b8ab8")
plt.savefig("lat_env.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Tolerance", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Society's Tolerance", color="#7b8ab8")
plt.savefig("lat_toler.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Startups", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Business Incorporation", color="#7b8ab8")
plt.savefig("lat_start.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Business Freedom", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Governmental Business Oversight", color="#7b8ab8")
plt.savefig("lat_biz.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Economy", grid=True, figsize=(8,8), 
                    title="Latitude's effect on overall Economic Health", color="#7b8ab8")
plt.savefig("lat_econ.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Taxation", grid=True, figsize=(8,8), 
                    title="Latitude's effect on relative Taxation Levels", color="#7b8ab8")
plt.savefig("lat_tax.png")
plt.show()

# %%
city_social_df.plot(kind="scatter", x="Lat", y="Internet Access", grid=True, figsize=(8,8), 
                    title="Latitude's effect on Access to the Internet", color="#7b8ab8")
plt.savefig("lat_internet.png")
plt.show()

# %%
import pandas as pd

# %%
# read the cities csv file
cities_df = pd.read_csv('cities.csv')

# save to file
cities_df.to_html('data_a.html', index=False)

# assign to string
table_a = cities_df.to_html()
print(table_a)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>jacareacanga</td>
#       <td>0</td>
#       <td>BR</td>
#       <td>1528902000</td>
#       <td>62</td>
#       <td>-6.22</td>
#       <td>-57.76</td>
#       <td>89.60</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>kaitangata</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1528905304</td>
#       <td>94</td>
#       <td>-46.28</td>
#       <td>169.85</td>
#       <td>42.61</td>
#       <td>5.64</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
# read the second csv file
soc_eco_df = pd.read_csv('uaScoresDataFrame.csv')

# save to file
soc_eco_df.to_html('data_b.html', index=False)

# assign to string
table_b = soc_eco_df.to_html()
print(table_b)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>UA_Name</th>
#       <th>UA_Country</th>
#       <th>UA_Continent</th>
#       <th>Housing</th>
#       <th>Cost of Living</th>
#       <th>Startups</th>
#       <th>Venture Capital</th>
#       <th>Travel Connectivity</th>
#       <th>Commute</th>
#       <th>Business Freedom</th>
#       <th>Safety</th>
#       <th>Healthcare</th>
#       <th>Education</th>
#       <th>Environmental Quality</th>
#       <th>Economy</th>
#       <th>Taxation</th>
#       <th>Internet Access</th>
#       <th>Leisure &amp; Culture</th>
#       <th>Tolerance</th>
#       <th>Outdoors</th>
#       <th>Lat</th>
#       <th>Lng</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Aarhus</td>
#       <td>Denmark</td>
#       <td>Europe</td>
#       <td>6.1315</td>
#       <td>4.015</td>
#       <td>2.8270</td>
# ...
